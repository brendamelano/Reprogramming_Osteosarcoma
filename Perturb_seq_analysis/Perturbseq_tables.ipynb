# %%
import plotly.figure_factory as ff
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a DataFrame with the provided information
data = {
  'Target': ['ctrl_pool', 'DDIT3', 'TSHZ2', 'STAT1', 'NR0B1', 'NFE2L3', 'TCF4','JUNB' , 'JUN', 'NFKB2', 'IRF1', 'ZIC2', 'KLF12'],
  'OS384': ['X', 'X', 'X','X', 'X','X', 'X','X', 'X','X', 'X','X', 'X'],
  'OS742': ['X', 'X', 'X','X', 'X','X', 'X','X', 'X','X', 'X','X', 'X'],
  'OS833': ['X', 'X', 'X','X', 'X','X', 'X','X', 'X','X', 'X','X', 'X']
}

df = pd.DataFrame(data)

# Plot table and remove axis
fig, ax = plt.subplots(figsize=(6, 2))  # Adjust the size as necessary
ax.axis('tight')
ax.axis('off')
ax.table(cellText=df.values, colLabels=df.columns, cellLoc='center', loc='center')
plt.savefig('/Users/brendamelano/Desktop/Perturbseq_table.svg', format='svg', bbox_inches='tight')

plt.show()
